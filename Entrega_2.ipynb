# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Cargamos el csv
data_frame = pd.read_csv("weatherAUS.csv")
data_frame.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
# Valores nulos
for feature in data_frame.columns:
    print('Total de valores nulos de', feature, '=', data_frame[feature].isna().sum())
# Out:
# Total de valores nulos de Date = 0
# Total de valores nulos de Location = 0
# Total de valores nulos de MinTemp = 637
# Total de valores nulos de MaxTemp = 322
# Total de valores nulos de Rainfall = 1406
# Total de valores nulos de Evaporation = 60843
# Total de valores nulos de Sunshine = 67816
# Total de valores nulos de WindGustDir = 9330
# Total de valores nulos de WindGustSpeed = 9270
# Total de valores nulos de WindDir9am = 10013
# Total de valores nulos de WindDir3pm = 3778
# Total de valores nulos de WindSpeed9am = 1348
# Total de valores nulos de WindSpeed3pm = 2630
# Total de valores nulos de Humidity9am = 1774
# Total de valores nulos de Humidity3pm = 3610
# Total de valores nulos de Pressure9am = 14014
# Total de valores nulos de Pressure3pm = 13981
# Total de valores nulos de Cloud9am = 53657
# Total de valores nulos de Cloud3pm = 57094
# Total de valores nulos de Temp9am = 904
# Total de valores nulos de Temp3pm = 2726
# Total de valores nulos de RainToday = 1406
# ...

# %%
# X: variable que tendrá las columnas para el análisis
X = data_frame.iloc[:, 0:-1]
pd.DataFrame(X).head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# ...

# %%
# Y: variable que tendrá la columna a predecir
y = data_frame.iloc[:, -1]
pd.DataFrame(y).head(10)
# Out:
#   RainTomorrow
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No
# 5           No
# 6           No
# 7           No
# 8          Yes
# 9           No

# %%
# Dejamos en una variable todas las columnas de tipo object
listObjType = X.select_dtypes(include = "object").columns
print (listObjType)
# Out:
# Index(['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm',
#        'RainToday'],
#       dtype='object')

# %%
# Transformamos todos los valores en números
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for item in listObjType:
    X[item] = le.fit_transform(X[item].astype(str))

print (X.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           142193 non-null  int32
#  1   Location       142193 non-null  int32
#  2   MinTemp        141556 non-null  float64
#  3   MaxTemp        141871 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81350 non-null   float64
#  6   Sunshine       74377 non-null   float64
#  7   WindGustDir    142193 non-null  int32
#  8   WindGustSpeed  132923 non-null  float64
#  9   WindDir9am     142193 non-null  int32
#  10  WindDir3pm     142193 non-null  int32
#  11  WindSpeed9am   140845 non-null  float64
#  12  WindSpeed3pm   139563 non-null  float64
#  13  Humidity9am    140419 non-null  float64
#  14  Humidity3pm    138583 non-null  float64
#  15  Pressure9am    128179 non-null  float64
#  16  Pressure3pm    128212 non-null  float64
# ...

# %%
X['Rainfall'] = X['Rainfall'].fillna((X['Rainfall'].mean()))
pd.DataFrame(X).head(100)

#Al ser variable con decimal es necesario utilizar el promedio
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6          NaN       NaN
# 1    397         2      7.4     25.1       0.0          NaN       NaN
# 2    398         2     12.9     25.7       0.0          NaN       NaN
# 3    399         2      9.2     28.0       0.0          NaN       NaN
# 4    400         2     17.5     32.3       1.0          NaN       NaN
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0          NaN       NaN
# 96   493         2     11.0     30.2       0.0          NaN       NaN
# 97   494         2     13.8     31.8       0.0          NaN       NaN
# 98   495         2     15.5     32.0       0.0          NaN       NaN
# 99   496         2     18.4     30.5       1.2          NaN       NaN
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
X['Evaporation'] = X['Evaporation'].fillna((X['Evaporation'].mean()))
pd.DataFrame(X).head(100)

#Al ser variable con decimal es necesario utilizar el promedio
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6     5.469824       NaN
# 1    397         2      7.4     25.1       0.0     5.469824       NaN
# 2    398         2     12.9     25.7       0.0     5.469824       NaN
# 3    399         2      9.2     28.0       0.0     5.469824       NaN
# 4    400         2     17.5     32.3       1.0     5.469824       NaN
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0     5.469824       NaN
# 96   493         2     11.0     30.2       0.0     5.469824       NaN
# 97   494         2     13.8     31.8       0.0     5.469824       NaN
# 98   495         2     15.5     32.0       0.0     5.469824       NaN
# 99   496         2     18.4     30.5       1.2     5.469824       NaN
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
X['Sunshine'] = X['Sunshine'].fillna((X['Sunshine'].mean()))
pd.DataFrame(X).head(100)

#Al ser variable con decimal es necesario utilizar el promedio
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6     5.469824  7.624853
# 1    397         2      7.4     25.1       0.0     5.469824  7.624853
# 2    398         2     12.9     25.7       0.0     5.469824  7.624853
# 3    399         2      9.2     28.0       0.0     5.469824  7.624853
# 4    400         2     17.5     32.3       1.0     5.469824  7.624853
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0     5.469824  7.624853
# 96   493         2     11.0     30.2       0.0     5.469824  7.624853
# 97   494         2     13.8     31.8       0.0     5.469824  7.624853
# 98   495         2     15.5     32.0       0.0     5.469824  7.624853
# 99   496         2     18.4     30.5       1.2     5.469824  7.624853
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
X['WindGustDir'] = X['WindGustDir'].fillna(X['WindGustDir'].mode()[0])
pd.DataFrame(X).head(100)

#Al ser un int se utilizara la moda para remplazar los nulos. Ya que la geografia del lugar determina con mayor frecuencia una dirección determinada para el viento
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6     5.469824  7.624853
# 1    397         2      7.4     25.1       0.0     5.469824  7.624853
# 2    398         2     12.9     25.7       0.0     5.469824  7.624853
# 3    399         2      9.2     28.0       0.0     5.469824  7.624853
# 4    400         2     17.5     32.3       1.0     5.469824  7.624853
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0     5.469824  7.624853
# 96   493         2     11.0     30.2       0.0     5.469824  7.624853
# 97   494         2     13.8     31.8       0.0     5.469824  7.624853
# 98   495         2     15.5     32.0       0.0     5.469824  7.624853
# 99   496         2     18.4     30.5       1.2     5.469824  7.624853
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
X['WindGustSpeed'] = X['WindGustSpeed'].fillna((X['WindGustSpeed'].mean()))
pd.DataFrame(X).head(100)

#Al ser variable con decimal es necesario utilizar el promedio
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6     5.469824  7.624853
# 1    397         2      7.4     25.1       0.0     5.469824  7.624853
# 2    398         2     12.9     25.7       0.0     5.469824  7.624853
# 3    399         2      9.2     28.0       0.0     5.469824  7.624853
# 4    400         2     17.5     32.3       1.0     5.469824  7.624853
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0     5.469824  7.624853
# 96   493         2     11.0     30.2       0.0     5.469824  7.624853
# 97   494         2     13.8     31.8       0.0     5.469824  7.624853
# 98   495         2     15.5     32.0       0.0     5.469824  7.624853
# 99   496         2     18.4     30.5       1.2     5.469824  7.624853
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
X['WindDir9am'] = X['WindDir9am'].fillna(X['WindDir9am'].mode()[0])
pd.DataFrame(X).head(100)

#Al ser un int se utilizara la moda para remplazar los nulos. Ya que la geografia del lugar determina con mayor frecuencia una dirección determinada para el viento
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0
indGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
X['Cloud9am'] = X['Cloud9am'].fillna((X['Cloud9am'].mean()))
pd.DataFrame(X).head(100)

#Al ser variable con decimal es necesario utilizar el promedio
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6     5.469824  7.624853
# 1    397         2      7.4     25.1       0.0     5.469824  7.624853
# 2    398         2     12.9     25.7       0.0     5.469824  7.624853
# 3    399         2      9.2     28.0       0.0     5.469824  7.624853
# 4    400         2     17.5     32.3       1.0     5.469824  7.624853
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0     5.469824  7.624853
# 96   493         2     11.0     30.2       0.0     5.469824  7.624853
# 97   494         2     13.8     31.8       0.0     5.469824  7.624853
# 98   495         2     15.5     32.0       0.0     5.469824  7.624853
# 99   496         2     18.4     30.5       1.2     5.469824  7.624853
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
X['Cloud3pm'] = X['Cloud3pm'].fillna((X['Cloud3pm'].mean()))
pd.DataFrame(X).head(100)

#Al ser variable con decimal es necesario utilizar el promedio
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6     5.469824  7.624853
# 1    397         2      7.4     25.1       0.0     5.469824  7.624853
# 2    398         2     12.9     25.7       0.0     5.469824  7.624853
# 3    399         2      9.2     28.0       0.0     5.469824  7.624853
# 4    400         2     17.5     32.3       1.0     5.469824  7.624853
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0     5.469824  7.624853
# 96   493         2     11.0     30.2       0.0     5.469824  7.624853
# 97   494         2     13.8     31.8       0.0     5.469824  7.624853
# 98   495         2     15.5     32.0       0.0     5.469824  7.624853
# 99   496         2     18.4     30.5       1.2     5.469824  7.624853
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
X['Cloud9am'] = X['Cloud9am'].fillna((X['Cloud9am'].mean()))
pd.DataFrame(X).head(100)

#Al ser variable con decimal es necesario utilizar el promedio
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6     5.469824  7.624853
# 1    397         2      7.4     25.1       0.0     5.469824  7.624853
# 2    398         2     12.9     25.7       0.0     5.469824  7.624853
# 3    399         2      9.2     28.0       0.0     5.469824  7.624853
# 4    400         2     17.5     32.3       1.0     5.469824  7.624853
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0     5.469824  7.624853
# 96   493         2     11.0     30.2       0.0     5.469824  7.624853
# 97   494         2     13.8     31.8       0.0     5.469824  7.624853
# 98   495         2     15.5     32.0       0.0     5.469824  7.624853
# 99   496         2     18.4     30.5       1.2     5.469824  7.624853
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
# Gráfico de densidad de Humedad

x_values = X.Humidity3pm.unique()
y_values = X.Humidity3pm.value_counts().tolist()
plt.scatter(x_values, y_values, marker='o');
#plt.plot(x_values, y_values)
plt.title('Densidad de Humedad a las 15:00 hrs')
plt.xlabel('Humedad')
plt.ylabel('Frecuencia')
plt.show()

# %%
X['Temp9am'] = X['Temp9am'].fillna((X['Temp9am'].mean()))
pd.DataFrame(X).head(100)

#Al ser variable con decimal es necesario utilizar el promedio
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0
indGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
X['MaxTemp'] = X['MaxTemp'].fillna(X['MaxTemp'].mode()[0])
pd.DataFrame(X).head(100)

# se elige la opción de moda ya que son valores que pueden alterar su valor con otro valor
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6     5.469824  7.624853
# 1    397         2      7.4     25.1       0.0     5.469824  7.624853
# 2    398         2     12.9     25.7       0.0     5.469824  7.624853
# 3    399         2      9.2     28.0       0.0     5.469824  7.624853
# 4    400         2     17.5     32.3       1.0     5.469824  7.624853
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0     5.469824  7.624853
# 96   493         2     11.0     30.2       0.0     5.469824  7.624853
# 97   494         2     13.8     31.8       0.0     5.469824  7.624853
# 98   495         2     15.5     32.0       0.0     5.469824  7.624853
# 99   496         2     18.4     30.5       1.2     5.469824  7.624853
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
# Comprobamos que no hay valores nulos
for feature in X.columns:
    print('Total de valores nulos de', feature, '=', X[feature].isna().sum())
# Out:
# Total de valores nulos de Date = 0
# Total de valores nulos de Location = 0
# Total de valores nulos de MinTemp = 0
# Total de valores nulos de MaxTemp = 0
# Total de valores nulos de Rainfall = 0
# Total de valores nulos de Evaporation = 0
# Total de valores nulos de Sunshine = 0
# Total de valores nulos de WindGustDir = 0
# Total de valores nulos de WindGustSpeed = 0
# Total de valores nulos de WindDir9am = 0
# Total de valores nulos de WindDir3pm = 0
# Total de valores nulos de WindSpeed9am = 0
# Total de valores nulos de WindSpeed3pm = 0
# Total de valores nulos de Humidity9am = 0
# Total de valores nulos de Humidity3pm = 0
# Total de valores nulos de Pressure9am = 0
# Total de valores nulos de Pressure3pm = 0
# Total de valores nulos de Cloud9am = 0
# Total de valores nulos de Cloud3pm = 0
# Total de valores nulos de Temp9am = 0
# Total de valores nulos de Temp3pm = 0
# Total de valores nulos de RainToday = 0
# Total de valores nulos de RISK_MM = 0

# %%
def getGraficoBarras(label_x, label_y, title, feature):
    x_values = X[feature].unique()
    y_values = X[feature].value_counts().tolist()
    plt.bar(x_values, y_values)
    plt.title(title)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.show()

getGraficoBarras('Indicador de Lluvia Hoy', 'Cantidad de registros', "Valor 0: No, 1: Si", 'RainToday')

# %%
tipos = X['RainToday'].unique()
total = X['RainToday'].value_counts().tolist()
plt.pie(total, labels=tipos, autopct='%1.1f%%', shadow=True, startangle=90) 
plt.title('Distribución de Lluvia Hoy')
plt.show()

# %%
# Gráfico de densidad de Humedad

x_values = X.Humidity9am.unique()
y_values = X.Humidity9am.value_counts().tolist()
plt.scatter(x_values, y_values, marker='o');
#plt.plot(x_values, y_values)
plt.title('Densidad de Humedad a las 09:00 hrs')
plt.xlabel('Humedad')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Gráfico de densidad de Humedad

x_values = X.Humidity3pm.unique()
y_values = X.Humidity3pm.value_counts().tolist()
plt.sc
atter(x_values, y_values, marker='o');
#plt.plot(x_values, y_values)
plt.title('Densidad de Humedad a las 15:00 hrs')
plt.xlabel('Humedad')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9724/2156249771.py in <module>
#       3 x_values = X.Humidity3pm.unique()
#       4 y_values = X.Humidity3pm.value_counts().tolist()
# ----> 5 plt.sc
#       6 atter(x_values, y_values, marker='o');
#       7 #plt.plot(x_values, y_values)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'sc'

# %%
### Visualizar diferencias de presion entre 9AM y 3 PM?
group_pressure_9 = X['Pressure9am'].groupby(X['Pressure9am'])
pd.DataFrame(group_pressure_9).head(100)
# Out:
#         0                                                  1
# 0   980.5   20809    980.5
# Name: Pressure9am, dtype: float64
# 1   982.0  102709    982.0
# Name: Pressure9am, dtype: float64
# 2   982.2  129450    982.2
# Name: Pressure9am, dtype: float64
# 3   982.3   96679    982.3
# Name: Pressure9am, dtype: float64
# 4   982.9  126973    982.9
# 129596    982.9
# Name: Pressure...
# ..    ...                                                ...
# 95  995.7  47501     995.7
# 55608     995.7
# 59515     995....
# 96  995.8  50500     995.8
# 56353     995.8
# 57833     995....
# 97  995.9  49483     995.9
# 72487     995.9
# 72988     995....
# 98  996.0  2551      996.0
# 60001     996.0
# 72991     996....
# 99  996.1  41379     996.1
# 44065     996.1
# 60021     996....
#
# [100 rows x 2 columns]

# %%
group_pressure_3 = X['Pressure3pm'].groupby(X['Pressure3pm'])
pd.DataFrame(group_pressure_3).head(100)
# Out:
#         0                                                  1
# 0   977.1  129513    977.1
# Name: Pressure3pm, dtype: float64
# 1   978.2  129523    978.2
# Name: Pressure3pm, dtype: float64
# 2   979.0   20809    979.0
# Name: Pressure3pm, dtype: float64
# 3   980.2  127090    980.2
# 130008    980.2
# Name: Pressure...
# 4   981.2  126973    981.2
# Name: Pressure3pm, dtype: float64
# ..    ...                                                ...
# 95  993.4  29228     993.4
# 43990     993.4
# 65476     993....
# 96  993.5  44091     993.5
# 50500     993.5
# 62511     993....
# 97  993.6  35572     993.6
# 65910     993.6
# 80603     993....
# 98  993.7  11494     993.7
# 59916     993.7
# 68444     993....
# 99  993.8  6590      993.8
# 94282     993.8
# 98992     993....
#
# [100 rows x 2 columns]

# %%
# Obtener temperatura promedio entre maxima y minima registrada a las 9am?

column = X["Temp9am"]

print(column.max() - column.min())
# Out:
# 47.400000000000006

# %%
#Mostrar velocidades de viento entre 9AM y 3PM?
### Agrupación de velocidad del viento a las 9 am
group_pressure_9 = X['WindSpeed9am'].groupby(X['WindSpeed9am'])
pd.DataFrame(group_pressure_9).head(100)
# Out:
#              0                                                  1
# 0     0.000000  25        0.0
# 85        0.0
# 87        0.0
# 94  ...
# 1     2.000000  48        2.0
# 81        2.0
# 98        2.0
# 104 ...
# 2     4.000000  1         4.0
# 23        4.0
# 35        4.0
# 60  ...
# 3     6.000000  7         6.0
# 16        6.0
# 22        6.0
# 33  ...
# 4     7.000000  4         7.0
# 8         7.0
# 41        7.0
# 42  ...
# 5     9.000000  19        9.0
# 24        9.0
# 49        9.0
# 56  ...
# 6    11.000000  3         11.0
# 15        11.0
# 28        11.0
# 3...
# 7    13.000000  26        13.0
# 40        13.0
# 63        13.0
# 1...
# 8    14.001988  14        14.001988
# 433       14.001988
# 434   ...
# 9    15.000000  9         15.0
# 11        15.0
# 39        15.0
# 5...
# 10   17.000000  10        17.0
# 18        17.0
# 20        17.0
# 2...
# 11   19.000000  2         19.0
# 5         19.0
# 21        19.0
# 2...
# 12   20.000000  0         20.0
# ...

# %%
### Agrupación de velocidad del viento a las 3 pm
group_pressure_9 = X['WindSpeed3pm'].groupby(X['WindSpeed3pm'])
pd.DataFrame(group_pressure_9).head(100)
# Out:
#             0                                                  1
# 0    0.000000  74        0.0
# 181       0.0
# 186       0.0
# 195 ...
# 1    2.000000  86        2.0
# 177       2.0
# 197       2.0
# 236 ...
# 2    4.000000  60        4.0
# 98        4.0
# 143       4.0
# 167 ...
# 3    6.000000  10        6.0
# 18        6.0
# 87        6.0
# 117 ...
# 4    7.000000  32        7.0
# 55        7.0
# 62        7.0
# 107 ...
# 5    9.000000  3         9.0
# 15        9.0
# 19        9.0
# 38  ...
# 6   11.000000  9         11.0
# 31        11.0
# 39        11.0
# 4...
# 7   13.000000  11        13.0
# 22        13.0
# 24        13.0
# 5...
# 8   15.000000  41        15.0
# 47        15.0
# 48        15.0
# 6...
# 9   17.000000  7         17.0
# 17        17.0
# 29        17.0
# 3...
# 10  18.637576  88        18.637576
# 400       18.637576
# 428   ...
# 11  19.000000  23        19.0
# 65        19.0
# 99        19.0
# 1...
# 12  20.000000  4         20.0
# 13        20.0
# ...

# %%
###    ENTREGA 2


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
X.head(100)
# Out:
#     Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    396         2     13.4     22.9       0.6     5.469824  7.624853
# 1    397         2      7.4     25.1       0.0     5.469824  7.624853
# 2    398         2     12.9     25.7       0.0     5.469824  7.624853
# 3    399         2      9.2     28.0       0.0     5.469824  7.624853
# 4    400         2     17.5     32.3       1.0     5.469824  7.624853
# ..   ...       ...      ...      ...       ...          ...       ...
# 95   492         2      8.3     27.9       0.0     5.469824  7.624853
# 96   493         2     11.0     30.2       0.0     5.469824  7.624853
# 97   494         2     13.8     31.8       0.0     5.469824  7.624853
# 98   495         2     15.5     32.0       0.0     5.469824  7.624853
# 99   496         2     18.4     30.5       1.2     5.469824  7.624853
#
#     WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
# Medidas estadísticas
X.describe()
# Out:
#                 Date       Location        MinTemp        MaxTemp  \
# count  142193.000000  142193.000000  142193.000000  142193.000000
# mean     1924.782908      23.740655      12.174813      23.219477
# std       886.165810      14.237503       6.391258       7.111209
# min         0.000000       0.000000      -8.500000      -4.800000
# 25%      1162.000000      11.000000       7.600000      17.900000
# 50%      1945.000000      24.000000      12.000000      22.600000
# 75%      2691.000000      36.000000      16.800000      28.200000
# max      3435.000000      48.000000      33.900000      48.100000
#
#             Rainfall    Evaporation       Sunshine    WindGustDir  \
# count  142193.000000  142193.000000  142193.000000  142193.000000
# mean        2.349974       5.469824       7.624853       8.255885
# std         8.423217       3.168114       2.734927       4.953096
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# Considerando solo las columnas de tipo object
import numpy as np
data_frame.describe(include=[object])
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count       142193    142193      132863     132180     138415    140787
# unique        3436        49          16         16         16         2
# top     2013-12-01  Canberra           W          N         SE        No
# freq            49      3418        9780      11393      10663    109332
#
#        RainTomorrow
# count        142193
# unique            2
# top              No
# freq         110316

# %%
# Se toma como muestra la humedad a las 9 am y 3 am y se compara contra la ráfaga de viento

for col in ['Humidity9am','Humidity3pm']:
    fig, ax =plt.subplots(1, 2, figsize=(20, 6))
    fig.suptitle(col, fontsize=18)
    sns.histplot(data_frame[col], ax=ax[0], kde=False)
    data_frame[[col]+['WindGustSpeed']].plot.scatter(x=col, y='WindGustSpeed', ax=ax[1])
    plt.show()

# %%
## Correlación de las variables
plt.figure(figsize=(15,15))
p=sns.heatmap(X.corr(), annot=True,cmap='RdYlGn',square=True)

# %%
data_frame.RainTomorrow.replace(('Yes', 'No'), (1, 0), inplace=True)
data_frame.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# Se toma como muestra la humedad y la velocidad del viento a las 9 am
Z = X[['Humidity9am','Humidity3pm']] 
Y = data_frame.RainTomorrow

# Separar los datos de "train" en entrenamiento y prueba para probar el modelo
Z_train, Z_test, Y_train, Y_test = train_test_split(Z, Y, test_size=0.2, random_state = 29)
modelo = DecisionTreeRegressor(max_depth = 5, random_state = 29)

# Entrenamiento del modelo
modelo.fit(Z_train, Y_train)

# Validación del modelo
Y_pred = modelo.predict(Z_test)

# Evaluación del modelo
print('Precisión del modelo (en entrenamiento):', modelo.score(Z_train, Y_train))
print('Precisión del modelo (en validación):', modelo.score(Z_test, Y_test))
# Out:
# Precisión del modelo (en entrenamiento): 0.2514581334444852
# Precisión del modelo (en validación): 0.24672449972666877

# %%
from sklearn.tree import plot_tree
fig, ax = plt.subplots(figsize=(30, 10))

print(f"Profundidad del árbol: {modelo.get_depth()}")
print(f"Número de nodos terminales: {modelo.get_n_leaves()}")

plot = plot_tree(
            decision_tree = modelo,
            feature_names = data_frame.drop(columns = ["WindGustSpeed", "Temp9am", "Temp3pm", "RainToday"]).columns,
            class_names   = 'RainToday',
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )

### Se descartan las columnas de temperatura y se da énfasis al día actual
# Out:
# Profundidad del árbol: 5
# Número de nodos terminales: 32

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 6)

plt.plot(Y_pred[:100], label='Predicted')
plt.plot(Y_test.values[:100], label='Actual')
plt.ylabel('RainToday')

plt.legend()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
### En conclusión al llover el día actual no es posible llegar a datos certeros que nos asegure un día lluvioso mañana.
### Por consiguiente procederemos a aplicar otro modelo esperando tener unos resultados más exactos.

# %%
### SEGUNDO MODELO: K-means
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# Importamos las librerías

# %%
data_frame.drop(['RainTomorrow','WindGustSpeed'],1).hist()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_9724/3218476467.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data_frame.drop(['RainTomorrow','WindGustSpeed'],1).hist()

# %% [raw]
# from sklearn.cluster import KMeans
# num_clusters = range(1, 20)
# kmeans = [KMeans(n_clusters=i) for i in num_clusters]
# kmeans
# score = [kmeans[i].fit(X).score(X) for i in range(len(kmeans))]
# score
# plt.plot(num_clusters,score)
# plt.xlabel('Número de Clusters')
# plt.ylabel('Score')
# plt.title('Elbow Curve')
# plt.show()

# %%
kmeans = KMeans(n_clusters=5).fit(X)
centroids = kmeans.cluster_centers_
print(centroids)

# %%
# Predicción del kluster
labels = kmeans.predict(X)
#Se obitene los ejes centrales del kluster
C = kmeans.cluster_centers_
# 5 colores porque k = 5
colores=['red','green','blue','cyan','yellow'] 
asignar=[]
for row in labels:
    asignar.append(colores[row])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=asignar,s=60)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c=colores, s=1000)
plt.show()
